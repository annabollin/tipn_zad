# %%
import pandas as pd

# %%
narko = pd.read_csv('drugs.csv')

# %%
narko
# Out:
#       age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 0      12  2798          3.9                3.0            1.1
# 1      13  2757          8.5                6.0            3.4
# 2      14  2792         18.1                5.0            8.7
# 3      15  2956         29.2                6.0           14.5
# 4      16  3058         40.1               10.0           22.5
# 5      17  3038         49.3               13.0           28.0
# 6      18  2469         58.7               24.0           33.7
# 7      19  2223         64.6               36.0           33.4
# 8      20  2271         69.7               48.0           34.0
# 9      21  2354         83.2               52.0           33.0
# 10  22-23  4707         84.2               52.0           28.4
# 11  24-25  4591         83.1               52.0           24.9
# 12  26-29  2628         80.7               52.0           20.8
# 13  30-34  2864         77.5               52.0           16.4
# ...

# %%
narko.head()
# Out:
#   age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 0  12  2798          3.9                3.0            1.1
# 1  13  2757          8.5                6.0            3.4
# 2  14  2792         18.1                5.0            8.7
# 3  15  2956         29.2                6.0           14.5
# 4  16  3058         40.1               10.0           22.5
#
#    marijuana-frequency  cocaine-use  cocaine-frequency  crack-use  \
# 0                  4.0          0.1                5.0        0.0
# 1                 15.0          0.1                1.0        0.0
# 2                 24.0          0.1                5.5        0.0
# 3                 25.0          0.5                4.0        0.1
# 4                 30.0          1.0                7.0        0.0
#
#    crack-frequency         ...          oxycontin-use  oxycontin-frequency  \
# 0              NaN         ...                    0.1                 24.5
# ...

# %%
narko.head(10)
# Out:
#   age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 0  12  2798          3.9                3.0            1.1
# 1  13  2757          8.5                6.0            3.4
# 2  14  2792         18.1                5.0            8.7
# 3  15  2956         29.2                6.0           14.5
# 4  16  3058         40.1               10.0           22.5
# 5  17  3038         49.3               13.0           28.0
# 6  18  2469         58.7               24.0           33.7
# 7  19  2223         64.6               36.0           33.4
# 8  20  2271         69.7               48.0           34.0
# 9  21  2354         83.2               52.0           33.0
#
#    marijuana-frequency  cocaine-use  cocaine-frequency  crack-use  \
# 0                  4.0          0.1                5.0        0.0
# 1                 15.0          0.1                1.0        0.0
# 2                 24.0          0.1                5.5        0.0
# ...

# %%
narko.tail()
# Out:
#       age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 12  26-29  2628         80.7               52.0           20.8
# 13  30-34  2864         77.5               52.0           16.4
# 14  35-49  7391         75.0               52.0           10.4
# 15  50-64  3923         67.2               52.0            7.3
# 16    65+  2448         49.3               52.0            1.2
#
#     marijuana-frequency  cocaine-use  cocaine-frequency  crack-use  \
# 12                 52.0          3.2                5.0        0.4
# 13                 72.0          2.1                8.0        0.5
# 14                 48.0          1.5               15.0        0.5
# 15                 52.0          0.9               36.0        0.4
# 16                 36.0          0.0                NaN        0.0
#
#     crack-frequency         ...          oxycontin-use  oxycontin-frequency  \
# 12              6.0         ...                    1.2                 13.5
# ...

# %%
narko.tail(10)
# Out:
#       age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 7      19  2223         64.6               36.0           33.4
# 8      20  2271         69.7               48.0           34.0
# 9      21  2354         83.2               52.0           33.0
# 10  22-23  4707         84.2               52.0           28.4
# 11  24-25  4591         83.1               52.0           24.9
# 12  26-29  2628         80.7               52.0           20.8
# 13  30-34  2864         77.5               52.0           16.4
# 14  35-49  7391         75.0               52.0           10.4
# 15  50-64  3923         67.2               52.0            7.3
# 16    65+  2448         49.3               52.0            1.2
#
#     marijuana-frequency  cocaine-use  cocaine-frequency  crack-use  \
# 7                  60.0          4.1                5.5        0.5
# 8                  60.0          4.9                8.0        0.6
# 9                  52.0          4.8                5.0        0.5
# ...

# %%
narko.tail(2)
# Out:
#       age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 15  50-64  3923         67.2               52.0            7.3
# 16    65+  2448         49.3               52.0            1.2
#
#     marijuana-frequency  cocaine-use  cocaine-frequency  crack-use  \
# 15                 52.0          0.9               36.0        0.4
# 16                 36.0          0.0                NaN        0.0
#
#     crack-frequency         ...          oxycontin-use  oxycontin-frequency  \
# 15             62.0         ...                    0.4                  5.0
# 16              NaN         ...                    0.0                  NaN
#
#     tranquilizer-use  tranquilizer-frequency  stimulant-use  \
# 15               1.4                    10.0            0.3
# 16               0.2                     5.0            0.0
#
#     stimulant-frequency  meth-use  meth-frequency  sedative-use  \
# 15                 24.0       0.2            30.0           0.2
# ...

# %%
narko.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 28 columns):
# age                        17 non-null object
# n                          17 non-null int64
# alcohol-use                17 non-null float64
# alcohol-frequency          17 non-null float64
# marijuana-use              17 non-null float64
# marijuana-frequency        17 non-null float64
# cocaine-use                17 non-null float64
# cocaine-frequency          16 non-null float64
# crack-use                  17 non-null float64
# crack-frequency            14 non-null float64
# heroin-use                 17 non-null float64
# heroin-frequency           16 non-null float64
# hallucinogen-use           17 non-null float64
# hallucinogen-frequency     17 non-null float64
# inhalant-use               17 non-null float64
# inhalant-frequency         16 non-null float64
# pain-releiver-use          17 non-null float64
# pain-releiver-frequency    17 non-null float64
# ...

# %%
narko['age']
# Out:
# 0        12
# 1        13
# 2        14
# 3        15
# 4        16
# 5        17
# 6        18
# 7        19
# 8        20
# 9        21
# 10    22-23
# 11    24-25
# 12    26-29
# 13    30-34
# 14    35-49
# 15    50-64
# 16      65+
# Name: age, dtype: object

# %%
narko['marijuana-use']
# Out:
# 0      1.1
# 1      3.4
# 2      8.7
# 3     14.5
# 4     22.5
# 5     28.0
# 6     33.7
# 7     33.4
# 8     34.0
# 9     33.0
# 10    28.4
# 11    24.9
# 12    20.8
# 13    16.4
# 14    10.4
# 15     7.3
# 16     1.2
# Name: marijuana-use, dtype: float64

# %%
narko[['marijuana-use', 'age']]
# Out:
#     marijuana-use    age
# 0             1.1     12
# 1             3.4     13
# 2             8.7     14
# 3            14.5     15
# 4            22.5     16
# 5            28.0     17
# 6            33.7     18
# 7            33.4     19
# 8            34.0     20
# 9            33.0     21
# 10           28.4  22-23
# 11           24.9  24-25
# 12           20.8  26-29
# 13           16.4  30-34
# 14           10.4  35-49
# 15            7.3  50-64
# 16            1.2    65+

# %%
lala = ['age','alcohol-use', 'marijuana-use']

# %%
narko[lala]
# Out:
#       age  alcohol-use  marijuana-use
# 0      12          3.9            1.1
# 1      13          8.5            3.4
# 2      14         18.1            8.7
# 3      15         29.2           14.5
# 4      16         40.1           22.5
# 5      17         49.3           28.0
# 6      18         58.7           33.7
# 7      19         64.6           33.4
# 8      20         69.7           34.0
# 9      21         83.2           33.0
# 10  22-23         84.2           28.4
# 11  24-25         83.1           24.9
# 12  26-29         80.7           20.8
# 13  30-34         77.5           16.4
# 14  35-49         75.0           10.4
# 15  50-64         67.2            7.3
# 16    65+         49.3            1.2

# %%
narko[6:10]
# Out:
#   age     n  alcohol-use  alcohol-frequency  marijuana-use  \
# 6  18  2469         58.7               24.0           33.7
# 7  19  2223         64.6               36.0           33.4
# 8  20  2271         69.7               48.0           34.0
# 9  21  2354         83.2               52.0           33.0
#
#    marijuana-frequency  cocaine-use  cocaine-frequency  crack-use  \
# 6                 52.0          3.2                5.0        0.4
# 7                 60.0          4.1                5.5        0.5
# 8                 60.0          4.9                8.0        0.6
# 9                 52.0          4.8                5.0        0.5
#
#    crack-frequency         ...          oxycontin-use  oxycontin-frequency  \
# 6             10.0         ...                    1.7                  7.0
# 7              2.0         ...                    1.5                  7.5
# 8              5.0         ...                    1.7                 12.0
# ...

# %%
narko['n'].sum()
# Out:
# 55268

# %%
narko['marijuana-frequency'].mean()
# Out:
# 42.94117647058823

# %%
narko['marijuana-frequency'].std()
# Out:
# 18.362565820968808

# %%
narko['marijuana-frequency'].min()
# Out:
# 4.0

# %%
narko['marijuana-frequency'].max()
# Out:
# 72.0

# %%
narko['marijuana-frequency'].median()
# Out:
# 52.0
